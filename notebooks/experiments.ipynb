# %% [markdown]
# Planning of experimentations :
# 1. Results Reproduction with original sounds
# 2. adding quantitative metrics
# 3. len(training_sample) variation
# 4. Audio Inpainting experiments
# 5. Denoising
# 6. Variation musicales et mesure de la diversité
#
# More advanced :
#
# 7. New Architectures
# 8. Addding perception losses for training
# 9. loss wav2vec / HuBERT for semantic representation

# %% [markdown]
# # 1. Reproduction des résultats

# %%
import os
import torch
import librosa
import soundfile as sf
import matplotlib.pyplot as plt
from IPython.display import Audio, display

# %%
AUDIO_PATH = "we_are_the_champions.wav"  # mets ton propre fichier ici
TARGET_SR = 44100 # Sampling rate (Hz) 
DURATION = 20  # seconds

# Load audio
x, sr = librosa.load(AUDIO_PATH, sr=TARGET_SR, mono=True)
x = x[:TARGET_SR * DURATION]

print(f"Loaded audio: {x.shape}, sr={sr}")

display(Audio(x, rate=sr))
# Out:
# Loaded audio: (882000,), sr=44100
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
FILE_NAME = "we_are_the_champion.wav"
TRAIN_WAV = f"../Catch-A-Waveform/inputs/{FILE_NAME}"
sf.write(TRAIN_WAV, x, TARGET_SR)
print("Training audio saved:", TRAIN_WAV)
# Out:
# Training audio saved: ../Catch-A-Waveform/inputs/we_are_the_champion.wav

# %%
# !ls ../Catch-A-Waveform/inputs
# Out:
# FMA_rock_for_inpainting.wav       trump_farewell_address_8.wav
# JosephJoachim_BachAdagio_1904.wav VCTK_p347_363_to_371.wav
# libDs4H.txt                       VCTK_p347_410_hr.wav
# p347_410.wav                      VCTK_p347_410_lr.wav
# TenorSaxophone_MedleyDB_185.wav   we_are_the_champion.wav

# %%
# !python ../Catch-A-Waveform/train_main.py \
    --input_file {FILE_NAME}
# Out:
# /Users/tristan/Documents/dev/02_cours_mva/07_deep_learning/project/Catch-A-Waveform-Review/Catch-A-Waveform/utils/utils.py:185: UserWarning: PySoundFile failed. Trying audioread instead.
#   samples, Fs = librosa.load(os.path.join('inputs', params.input_file), sr=None,
# /Users/tristan/Documents/dev/02_cours_mva/07_deep_learning/project/Catch-A-Waveform-Review/.envproject/lib/python3.14/site-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# Traceback (most recent call last):
#   File "/Users/tristan/Documents/dev/02_cours_mva/07_deep_learning/project/Catch-A-Waveform-Review/.envproject/lib/python3.14/site-packages/librosa/core/audio.py", line 176, in load
#     y, sr_native = __soundfile_load(path, offset, duration, dtype)
#                    ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tristan/Documents/dev/02_cours_mva/07_deep_learning/project/Catch-A-Waveform-Review/.envproject/lib/python3.14/site-packages/librosa/core/audio.py", line 209, in __soundfile_load
#     context = sf.SoundFile(path)
#   File "/Users/tristan/Documents/dev/02_cours_mva/07_deep_learning/project/Catch-A-Waveform-Review/.envproject/lib/python3.14/site-packages/soundfile.py", line 690, in __init__
#     self._file = self._open(file, mode_int, closefd)
#                  ~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tristan/Documents/dev/02_cours_mva/07_deep_learning/project/Catch-A-Waveform-Review/.envproject/lib/python3.14/site-packages/soundfile.py", line 1265, in _open
#     raise LibsndfileError(err, prefix="Error opening {0!r}: ".format(self.name))
# soundfile.LibsndfileError: Error opening 'inputs/we_are_the_champion.wav': System error.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/tristan/Documents/dev/02_cours_mva/07_deep_learning/project/Catch-A-Waveform-Review/notebooks/../Catch-A-Waveform/train_main.py", line 50, in <module>
#     samples = get_input_signal(params)
#   File "/Users/tristan/Documents/dev/02_cours_mva/07_deep_learning/project/Catch-A-Waveform-Review/Catch-A-Waveform/utils/utils.py", line 185, in get_input_signal
#     samples, Fs = librosa.load(os.path.join('inputs', params.input_file), sr=None,
#                   ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#                                offset=params.start_time, duration=2 * params.max_length)
#                                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tristan/Documents/dev/02_cours_mva/07_deep_learning/project/Catch-A-Waveform-Review/.envproject/lib/python3.14/site-packages/librosa/core/audio.py", line 184, in load
#     y, sr_native = __audioread_load(path, offset, duration, dtype)
#                    ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tristan/Documents/dev/02_cours_mva/07_deep_learning/project/Catch-A-Waveform-Review/.envproject/lib/python3.14/site-packages/decorator.py", line 235, in fun
#     return caller(func, *(extras + args), **kw)
#   File "/Users/tristan/Documents/dev/02_cours_mva/07_deep_learning/project/Catch-A-Waveform-Review/.envproject/lib/python3.14/site-packages/librosa/util/decorators.py", line 63, in __wrapper
#     return func(*args, **kwargs)
#   File "/Users/tristan/Documents/dev/02_cours_mva/07_deep_learning/project/Catch-A-Waveform-Review/.envproject/lib/python3.14/site-packages/librosa/core/audio.py", line 240, in __audioread_load
#     reader = audioread.audio_open(path)
#   File "/Users/tristan/Documents/dev/02_cours_mva/07_deep_learning/project/Catch-A-Waveform-Review/.envproject/lib/python3.14/site-packages/audioread/__init__.py", line 126, in audio_open
#     return BackendClass(path)
#   File "/Users/tristan/Documents/dev/02_cours_mva/07_deep_learning/project/Catch-A-Waveform-Review/.envproject/lib/python3.14/site-packages/audioread/rawread.py", line 59, in __init__
#     self._fh = open(filename, 'rb')
#                ~~~~^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: 'inputs/we_are_the_champion.wav'

# %%
# !python ../Catch-A-Waveform/main.py \
    --input_wav data/single_example/train.wav \
    --exp_name caw_unconditional \
    --sr 16000 \
    --epochs 3000 \
    --run_mode unconditional \
    --alpha_rec 0 \
    --alpha_mss 1e-4 \
    --cuda

# %% [markdown]
# # 2. Variation de la durée du training sample

# %% [markdown]
# # 3. Audio Inpainting & Denoising
